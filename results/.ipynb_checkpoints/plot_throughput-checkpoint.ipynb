# %%
import csv
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
def get_max_throughputs(directory, policy):
    throughputs = defaultdict(float)
    with open('/home/stephanie/ray-fork/results/{}/{}.csv'.format(directory, policy), 'r') as f:
        reader = csv.DictReader(f)
        for row in reader:
            num_shards = float(row['num_shards'])
            throughput = float(row['throughput'])
            if throughput == -1:
                continue
            if row['lineage'] == 'True' or row['queue'] == 'True' or row['timed_out'] == 'True':
                continue
            if throughput > throughputs[num_shards]:
                throughputs[num_shards] = throughput
    throughputs = list(throughputs.items())
    throughputs.sort(key=lambda x: x[0])
    return zip(*throughputs)

# %%
def plot(plt, directory, policy, label=None, marker=None):
    if label is None:
        label = policy
    try:
        x, y = get_max_throughputs(directory, policy)
    except:
        return
    l, = plt.plot(x, y, label=label, marker=marker)
    return l

# %%
from matplotlib.lines import Line2D

SAVE = False
DIRECTORY = "results-pingpong"
POLICIES = [
    'lineage-cache-100',
    'lineage-cache-flush-100',
    'lineage-cache-k-flush-100',
    'gcs',
]

LABELS = [
    'Lineage stash, in order',
    'Lineage stash, flush immediately',
    'Lineage stash, commit k',
    'GCS',
]

markers = [m for m, func in Line2D.markers.items()
           if func != 'nothing' and m in Line2D.filled_markers]
lines = [plot(plt, DIRECTORY, policy, label=label, marker=marker) for policy, label, marker in zip(POLICIES, LABELS, markers)]
lines = [(line, label) for line, label in zip(lines, LABELS) if line is not None]
lines, labels = zip(*lines)

plt.legend(lines, labels=labels)
plt.xlabel("Number of shards")
plt.ylabel("Maximum task submission rate")

if SAVE:
    plt.savefig("/home/stephanie/ray-fork/results/{}/throughput.pdf".format(DIRECTORY))
else:
    plt.show()
# Out:
# /home/stephanie/miniconda2/envs/ray-py3/lib/python3.5/site-packages/matplotlib/axes/_axes.py:518: UserWarning: You have mixed positional and keyword arguments, some input will be discarded.
#   warnings.warn("You have mixed positional and keyword "
